# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-wired-connectivity-issues/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Wired Connectivity Issues``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Wired Connectivity Issues](#topwiredConnectivityIssues)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topwiredConnectivityIssuesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topwiredConnectivityIssues"></a>
# ### [Wired Connectivity Issues](#wiredConnectivityIssues)
#
# - [1. Course Introduction](#wiredConnectivityIssues1CourseIntroduction) <br/><br/>
# - [2. Attenuation, Latency, and Jitter](#wiredConnectivityIssues2AttenuationLatencyandJitter) <br/><br/>
# - [3. Crosstalk and EMI](#wiredConnectivityIssues3CrosstalkandEMI) <br/><br/>
# - [4. Opens and Shorts](#wiredConnectivityIssues4OpensandShorts) <br/><br/>
# - [5. Incorrect Pinouts and Cable Types](#wiredConnectivityIssues5IncorrectPinoutsandCableTypes) <br/><br/>
# - [6. Duplex and Transceiver Mismatches](#wiredConnectivityIssues6DuplexandTransceiverMismatches) <br/><br/>
# - [7. Bad Ports, Bootlenecks, and VLAN Mismatches](#wiredConnectivityIssues7BadPortsBootlenecksandVLANMismatches) <br/><br/>
# - [8. Damaged Cables and Bent Pins](#wiredConnectivityIssues8DamagedCablesandBentPins) <br/><br/>
# - [9. LED Status Indicators](#wiredConnectivityIssues9LEDStatusIndicators)

# %% [markdown]
# ### [Practice: Wired Connectivity Issues](#wiredConnectivityIssuespractice)
#
# * [1. Exercise: Troubleshoot Wired Connectivity Issues](#wiredConnectivityIssuesexercise)

# %% [markdown]
# <a id="topwiredConnectivityIssuesTest"></a>
# ### ⚡ [Test](#wiredConnectivityIssuesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues"></a>
# ***
# ### Wired Connectivity Issues
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues1CourseIntroduction"></a>
# ***
# ###### 1. Course Introduction
# ***

# %% [markdown]
# Cover how to troubleshoot common wired connectivity issues.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues2AttenuationLatencyandJitter"></a>
# ***
# ###### 2. Attenuation, Latency, and Jitter
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot attenuation, latency and jitter given a scenario``

# %% [markdown]
# In this presentation we'll take a look at some of the factors that can contribute to poor signal quality, specifically over wired connections.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Attenuation
# ***

# %% [markdown]
# Beginning with attenuation, this refers to the reduction of signal strength while transmitting over long distances.

# %% [markdown]
# And this is applicable to both analog and digital transmissions because in both cases you are still pushing an electrical signal down a physical wire.

# %% [markdown]
# So sooner or later it will just run out of strength, it will not last forever, of course.

# %% [markdown]
# So the amount of attenuation is measured in decibels.

# %% [markdown]
# And, in fact, you might have something like a stereo amplifier at home that actually refers to the volume as attenuation. So it quite literally gets quieter, if you will, the farther it has to travel down that wire.

# %% [markdown]
# Now you might see it also measured in terms of voltage. But again, sooner or later the signal strength will just degrade to the point where it is no longer detectable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Attenuation - Transmission Medium
# ***

# %% [markdown]
# So in terms of the causes, the transmission medium itself is in essence the main cause.

# %% [markdown]
# As you push an electrical signal down a metal wire it causes an electromagnetic field. And this in essence saps energy from the transmission of the packet itself and goes into creating the field.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Attenuation - Crosstalk
# ***

# %% [markdown]
# So this can also happen with adjacent cabling because, of course, they are doing the exact same thing your cable is doing.

# %% [markdown]
# So they all generate these electromagnetic fields, and they can actually interfere with each other to a degree.

# %% [markdown]
# And this is why you see things like shielded cabling to reduce that as much as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Attenuation - Conductors
# ***

# %% [markdown]
# But also different conductors. The different types of materials that are used as a signal passes from, let's say, the physical wire, into something like a router or a switch or any other interconnectivity device. Or even from network to network where the material changes.

# %% [markdown]
# So all of that can contribute to attenuation.

# %% [markdown]
# But for the most part it is simply the resistance of the cable itself. Again, signals do not travel forever down a physical medium.

# %% [markdown]
# So sooner or later, they just die out.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency
# ***

# %% [markdown]
# Latency is an expression of how long it takes for data to get from one point to another.

# %% [markdown]
# Quite simply, the amount of time. And any given delay can typically be cumulative.

# %% [markdown]
# In other words, a bottleneck in one area can certainly have an effect elsewhere because you need to wait until everything gets through in many cases before you can process something and move it on its way.

# %% [markdown]
# So ideal conditions in a perfect world, latency should be as close to zero as possible.

# %% [markdown]
# Now, of course, you'll never actually see zero, it has to travel some distance therefore it must take some amount of time.

# %% [markdown]
# But the closer you can get to zero, the better.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Propagation
# ***

# %% [markdown]
# So in terms of the causes of latency, propagation refers to the amount of time it takes for data to travel from source to destination.

# %% [markdown]
# But in many cases it's source to multiple destinations, there are many instances where you send packets to more than one location.

# %% [markdown]
# So it's sort of the cumulative effect, if you will. In other words it's the amount of time it takes for all packets to reach all destinations. That refers to the latency in total.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Transmission Medium
# ***

# %% [markdown]
# And, of course, the transmission medium itself is going to have an effect.

# %% [markdown]
# Ethernet versus fiber will certainly vary in terms of the latency, because let's say copper wire Ethernet typically maxes out at about 100 meters.

# %% [markdown]
# Therefore you have to pass the signal through many more interconnection devices to traverse a long distance.

# %% [markdown]
# Whereas fiber can travel for kilometers before it ever needs to be boosted or passed through any kind of interconnection device.

# %% [markdown]
# So it's just all those stops, if you will, that an Ethernet environment has to implement that will quite simply delay the delivery of the packet.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Network Devices
# ***

# %% [markdown]
# Network devices such as routers also will increase the latency because they have to examine the packets and make a decision as to where it needs to go.

# %% [markdown]
# And it also has to increment the hop count. Every time it passes a router, it increments that hop count to in essence say it passed over another router.

# %% [markdown]
# Distance vector routing protocols use that hop count. So they have to process the packet.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Hard Disk Access
# ***

# %% [markdown]
# And hard disk access delays, of course, just simply retrieving the data in the first place, will take some time.

# %% [markdown]
# Then how much does it have to be switched? Which bridges does it have to cross? Things along those lines. So again, just more processing has to come into the picture.

# %% [markdown]
# So the more processing that's involved, the longer it will take.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Jitter
# ***

# %% [markdown]
# And jitter refers to deviation in a signal pulse with respect to its amplitude, its phase timing and or the width of the signal pulse.

# %% [markdown]
# And there can also be, of course, the variation in latency due to the fact that some packets take longer to arrive at any given system than do others.

# %% [markdown]
# So all of this can result in jitter.

# %% [markdown]
# And network congestion, timing drift, and route changes can certainly contribute to jitter.

# %% [markdown]
# And this is something that is typically a problem in real-time communication such as IP telephony, or voice over IP, or video conferencing. That's where you notice it the most.

# %% [markdown]
# Because if a packet arrives out of sequence or just in the wrong order, then this has to be reassembled and causes a delay. So that's when you just really see it the most.

# %% [markdown]
# When it's something that's not really concerned with real-time such as transferring a file, you don't ever really see it. It might still take a little more time but it's not something you notice, the file still comes up in its exact correct state.

# %% [markdown]
# But real-time communications ideally would like to see the least amount of latency and the least amount of jitter, so that the communication goes as smoothly as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues3CrosstalkandEMI"></a>
# ***
# ###### 3. Crosstalk and EMI
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario troubleshoot crosstalk and EMI``

# %% [markdown]
# In this presentation, we'll take a look at crosstalk and electromagnetic interference.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Crosstalk
# ***

# %% [markdown]
# Now crosstalk occurs when signals from one wire interfere with signals on another.

# %% [markdown]
# Now this is a more specific symptom of the larger problem, if you will.

# %% [markdown]
# In other words, it is caused by electromagnetic interference. But it quite simply refers to the fact that any given electric signal can cross from one wire to another when they are in very close proximity to each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In terms of measuring it, this is a matter of perspective, if you will.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Crosstalk - Near-end (NEXT)
# ***

# %% [markdown]
# In other words, if I'm at one end of any given connection and you are at the other, then it's sort of a matter of well, is the problem on my end or your end?

# %% [markdown]
# So this obviously depends on the perspective, but near-end crosstalk, or NEXT, is found close to the connector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Crosstalk - Far-end (FEXT)
# ***

# %% [markdown]
# And far-end crosstalk, or FEXT, is similar but at the far end.

# %% [markdown]
# So again, from my prospective, is it on my end or your end?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Complications - Error (Noise)
# ***

# %% [markdown]
# So the complications that can arise of course include really any kind of error and noise, quite literally.

# %% [markdown]
# Now in terms of noise, you might actually remember back in days of purely analog phone calls. You could actually hear someone on another line from time to time. This was due to crosstalk.

# %% [markdown]
# Now it's not as big a deal anymore with digital communications and quite simply better isolation.

# %% [markdown]
# But you literally could hear other people in those scenarios.

# %% [markdown]
# Now in terms of digital communication such as transferring a file, we don't really think of it as something that you can hear. But it is still interference, so we call it noise.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Complications - Packet Loss
# ***

# %% [markdown]
# Other complications include packet loss.

# %% [markdown]
# Now it's not the fact that a packet might entirely disappear. It might still arrive, but some of the data is no longer intact.

# %% [markdown]
# So there's a certain amount of loss of data and flat out transmission failure. Where a packet just does not arrive at all, and then of course, you end up having to retransmit.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Prevention - Twisted Pair Cable or better yet Shielded Cable
# ***

# %% [markdown]
# So in terms of prevention, you can implement twisted pair cable, or better yet, shielded cable.

# %% [markdown]
# But even if it is unshielded, the twisted pair cabling does provide a little bit of extra insulation, because you are twisting the pairs of cables around each other.

# %% [markdown]
# So that does give you that little bit of extra insulation.

# %% [markdown]
# But shielded cable, of course, will work better.

# %% [markdown]
# But if it's too bad, then you might need to physically separate those cables.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Electromagnetic Interference
# ***

# %% [markdown]
# So as mentioned, crosstalk is a little bit of a more specific symptom of a larger problem, electromagnetic interference.

# %% [markdown]
# And this is any kind of interference caused by any kind of electromagnetic disturbance.

# %% [markdown]
# And this can affect the overall performance of really any type of device or any type of data transmission.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Electromagnetic Interference - Radio Frequency Interference
# ***

# %% [markdown]
# Now closely related to that is also radio frequency interference.

# %% [markdown]
# And this of course is any kind of interference that is occurring on a radio frequency spectrum, such as two devices trying to transmit on the same frequency to the same device.

# %% [markdown]
# It would be like trying to tune your radio to two channels at the same time. Clearly they would just interfere with each other, but radio frequency is still a type of electromagnetic transmission.

# %% [markdown]
# So those two are closely related.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Electromagnetic Interference - Conducted EMI or Induction
# ***

# %% [markdown]
# Now this of course can be caused by direct physical contact with a conductor.

# %% [markdown]
# And this is referred to conducted EMI or induction, where there's no physical contact but rather radiated EMI.

# %% [markdown]
# Being too close to an electromagnetic field, such as electric power cords or unshielded cabling.

# %% [markdown]
# Now this is commonly observed with radios and as mentioned, this is sort the static noise heard when switching between channels. But if it was possible to tune into two channels at the same time, it would still be fairly illegible. You wouldn't be able to understand what's happening.

# %% [markdown]
# And even with the TV, the picture can become distorted when the signal weakens, due to the interference.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Avoid
# ***

# %% [markdown]
# So ideally, what you want to try to do is just avoid it in the first place, so keep away from heavy machinery, any kind of motor, generator.

# %% [markdown]
# Use shielded cables when necessary, so in ethernet, for example, STP, shielded twisted pair.

# %% [markdown]
# And if necessary, some sort of EMI filter. Something that can quite literally shield your cables, for example, from the EMI, so that you can just have the best conditions possible in terms of communication from point A to point B.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues4OpensandShorts"></a>
# ***
# ###### 4. Opens and Shorts
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario troubleshoot opens or cable shorts``

# %% [markdown]
# In this presentation, we'll take a look at two possible problems with wired connections known as shorts and opens.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Short
# ***

# %% [markdown]
# Now, a short quite simply refers to a short circuit.

# %% [markdown]
# And this is generally due to a section of a wire that has maybe become exposed and has come into contact with something else that can carry any kind of current.

# %% [markdown]
# So if for example, we are talking about electrical cabling, then quite literally, the cables might have come into contact with a metal frame, or even with each other. And this additional point of contact has provided an alternate path at very low impedance or resistance for that current to follow.

# %% [markdown]
# So because of this at the physical level, the circuit can overheat. You get a build up of too much power at that point, which clearly can damage the components and even cause a fire. Again, if you're talking about flat out power cabling.

# %% [markdown]
# Now when it comes to networking problems, an intermittent short can certainly still cause network issues, such as broadcast storms or intermittent periods of no network traffic. Now this could be caused by something such as a faulty network adapter or even an entire switch. Or maybe there's issues with the power itself. If it's spiking, for example, that can actually cause an arc whereby a current is quite literally able to jump from one place to another when there is no actual physical contact. Now, it's usually when they're very close, but it's something that of course might go away on its own.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Continuous Short
# ***

# %% [markdown]
# But if you have a continuous short, then this will cause continuous packet collisions and continuous broadcast storms because we are literally talking about now physical wires touching each other.

# %% [markdown]
# So in that event it will always result in a collision and this generally means that something is flat out broken and needs to be replaced.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Test - Low-voltage - High-voltage
# ***

# %% [markdown]
# So there are two common ways to test for a short and is quite simply the voltage.

# %% [markdown]
# Now it's either a low voltage test or a high voltage test depending on what it is you're dealing with.

# %% [markdown]
# In other words if you are talking about electrical cabling, then that is a relatively high voltage.

# %% [markdown]
# Your standard power, for example in your house or your office, runs up around 120 volts.

# %% [markdown]
# So relatively speaking, in terms of network communications, that's very high voltage.

# %% [markdown]
# But a packet running around on a network wire is much, much lower in terms of the voltage so it depends on what you are testing.

# %% [markdown]
# But if it is fairly high in terms of its voltage, so again power, you might actually be able to visually identify where it's happening. Because if it's exposed and in contact with something else, you can very likely see sparks coming from that point.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Open
# ***

# %% [markdown]
# So an open is the effective opposite of a short.

# %% [markdown]
# An open is when a cable connection is not continuous to the intended termination.

# %% [markdown]
# In other words it might simply be disconnected or maybe something has cut the cable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Test - Continuity Test - Resistance Test
# ***

# %% [markdown]
# So there are two ways to test for an open.

# %% [markdown]
# A continuity test, meaning is it continuous, or a resistance test. Do you see the correct amount of resistance? Because again, every electrical type of cabling, or any cable that is carrying an electric signal offers some kind of resistance. And it should be consistent throughout the entire cable.

# %% [markdown]
# In other words the resistance should not vary. So, if I take a cable and cut it in half and separate those two ends, that is in essence infinite resistance. There's no way it can push that current across the break.

# %% [markdown]
# So again, you can test for either and if it's, again, an open, clearly this is going to prevent the current from flowing. So any kind of network communication is clearly going to be ceased.

# %% [markdown]
# Now you can, again, try to track these down by using a toner probe, which sends a fairly strong electromagnetic current down the cable. And you can try to pick up on that, on the other end, or you can also just touch the two ends of the cable to the probe. And if you don't hear a tone, then the cable has an open somewhere.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In other words, it is simply not getting from one end all the way to the other end, and in many cases, it's just the cable has become disconnected. Somebody might have tripped over it and pulled it out. It's a matter of simply plugging it back in.

# %% [markdown]
# But if, of course, they damaged the cable when they pulled it out, then you might need to replace the cable, but those of course are fairly easy fixes.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Electrical Problems - Replace - Ultimately try to identify and correct Shorts and Opens
# ***

# %% [markdown]
# If you are talking about electrical problems within a device itself, you might be looking at needing to replace the whole device. But ultimately you want to try to identify and correct shorts and opens as quickly as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues5IncorrectPinoutsandCableTypes"></a>
# ***
# ###### 5. Incorrect Pinouts and Cable Types
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario troubleshooting incorrect pinouts and cable types``

# %% [markdown]
# Now, in this presentation, we'll take a look at the issues that you might encounter with respect to wiring an Ethernet environment.

# %% [markdown]
# We'll start with some actual wiring patterns for a standard Ethernet cable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T-568A
# ***

# %% [markdown]
# The T-568A was used originally for Ethernet connectivity, and is in essence what you will find with unshielded twisted pair cable.

# %% [markdown]
# And it does use an RJ-45 connector. You see the actual pattern of wires here.

# %% [markdown]
# If you look closely, you'll see a mix of solid colors with essentially a white wire and a matching color in stripes.

# %% [markdown]
# And it does actually list the colors in the connector in some cases.

# %% [markdown]
# You can see the upper case letter indicates the solid color, and the lower case letter indicates the stripe color.

# %% [markdown]
# Other than that, G of course is for green. B for blue, O for orange, and BR for brown. [The wires in a T-568A RJ-45 connector are as follows: 1: white and green, 2: solid green, 3: white and orange, 4: solid blue, 5: white and blue, 6: solid orange, 7: white and brown, and 8: solid brown. ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But those were the pen assignments for the T-568A.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T-568B
# ***

# %% [markdown]
# But that was superseded by the T-568B in 2002.

# %% [markdown]
# So this is now the most commonly chosen wiring schematic. [The wires in a T-568B RJ-45 connector are as follows: 1: white and orange, 2: solid orange, 3: white and green, 4: solid blue, 5: white and blue, 6: solid green, 7: white and brown, and 8: solid brown. ]

# %% [markdown]
# And it just accommodates the current and future needs of the cable as specifications change and evolve.

# %% [markdown]
# So its just a different pattern, but if you're making your own cables, in essence, you just want to ensure that you follow the T-568B specification.

# %% [markdown]
# And of course you are consistent on both ends of the cable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Crossover Cable
# ***

# %% [markdown]
# Now, in some cases, you might need a cross over cable, and this is used to connect computing devices of the same type together.

# %% [markdown]
# For example, you might need to connect a computer directly to another computer without a switch or a hub. You would want to use a crossover cable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, in this diagram, you can see that a crossover cable has a straight through end on one side and a crossover end on the other. [In an EIA/TIA-568B crossover cable, the order of wires in the straightthrough end is as follows: 1: white and orange, 2: solid orange, 3: white and green, 4: solid blue, 5: white and blue, 6: solid green, 7: white and brown, and 8: solid brown. In the crossover end, the wire order is as follows: 1: white and green, 2: solid green, 3: white and orange, 4: white and brown, 5: solid brown, 6: solid orange, 7: solid blue, and 8: white and blue.]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Rule of Three
# ***

# %% [markdown]
# The crossover follows what is sometimes known as the rule of three, where wire one is going to swap with wire three.

# %% [markdown]
# Wire two is going to swap with wire six, and vice versa, of course. [As an example, in the EIA/TIA-568B crossover cable, the white and orange wire is wire 1 in the straightthrough end and wire 3 in the crossover end.] 1 times 3 is 3, 2 times 3 is 6. Those are the swapped wires.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This ensures that what is transmitted out of one pin in the sender's network ends up getting forwarded to the receipt pin of the destination network card.

# %% [markdown]
# This process happens automatically when going through a switch or hub. But as we said, if that is missing, you need this type of cable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Creating Cable - Tools
# ***

# %% [markdown]
# Now, if you're purchasing your cabling from a manufacturer and confidence that they're a quality manufacturer, it's going to be very unlikely that the pinout is incorrect. But if you're creating your own cable, this requires tools, connectors, cables, crimpers, most notably. And, of course, you're more prone to wiring errors in this case.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting - TX/RX Reverse Issue
# ***

# %% [markdown]
# So when it comes to troubleshooting any of these issues, for starters, certainly being mindful of whether or not it should be a crossover instead of a straight through, which are, by far, the more common.

# %% [markdown]
# But when, again, you need that switchless computer to computer Ethernet connection, it does need to be a crossover.

# %% [markdown]
# If you use the wrong type of cable, then your network card will be listening for frames on a wire used for the send pin. And trying to send packets out the pin that should be used for receiving them.

# %% [markdown]
# This problem is called the transmit receive reverse issue. [Or TX/RX reverse issue. ]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting - Source of Interference
# ***

# %% [markdown]
# Another issue, is there any source of interference that's been identified?

# %% [markdown]
# Should you use a shielded cable, for example?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting - Cat 5 or Cat 6
# ***

# %% [markdown]
# What's the category, Cat 5 or Cat 6?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting - Using the Right Connector
# ***

# %% [markdown]
# And of course, is the cable using the right connector?

# %% [markdown]
# And obviously, you need to ensure that you are being consistent with everything when it comes to the connectors. They always have to be the same, of course. And if it is an issue of a bad connector, Ethernet over twisted pair, use what's known as an 8P8C, 8.8 contact.

# %% [markdown]
# Because there are eight wires on an RJ45, these days those two terms are used pretty much interchangeably.

# %% [markdown]
# And of course, when crimping, those connectors cut into the wire to form the connection itself.

# %% [markdown]
# But a bad connector can appear to be correctly attached, yet it did not quite form the proper electrical contact.

# %% [markdown]
# So again, when crimping, make sure that you test the cable, and that it is verified to work before you actually put it in production. Because again, you can be a little more prone to errors when crimping your own.

# %% [markdown]
# Again, the manufacturers that make these day-in day-out for the most part are using machines to produce them, so they're a lot more accurate than doing it by hand.

# %% [markdown]
# So always be mindful of those issues that can arise. If you're crimping your own, that's certainly fine, but just be a little more careful and ensure that you test the cable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues6DuplexandTransceiverMismatches"></a>
# ***
# ###### 6. Duplex and Transceiver Mismatches
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot duplex and transceiver mismatches given a scenario``

# %% [markdown]
# Another communications error that can arise is one known as a duplex mismatch.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Half Duplex
# ***

# %% [markdown]
# Now in terms of just communicating, there is a method known as half duplex, whereby you use a single channel of communication.

# %% [markdown]
# Now you can both send and receive on that channel, but it has to be one at a time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Full Duplex
# ***

# %% [markdown]
# Full duplex, which is implemented in technologies such as 10BaseT, Ethernet switches, and some wide area networking technologies, uses separate channels or wires.

# %% [markdown]
# And as such you can send and receive at the same time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Duplex Mismatch - Auto Negotiation - 802.3u
# ***

# %% [markdown]
# So if you have devices that are capable of doing either, they need to be matched.

# %% [markdown]
# And this was defined as what's known as auto negotiation. This was an implementation known as the IEEE 802.3u standard.

# %% [markdown]
# And this eliminates the need to manually configure settings on each network device.

# %% [markdown]
# The devices quite literally choose the common transmission parameters between them including the speed, the duplex mode and the flow.

# %% [markdown]
# So this eliminates a lot of problems in terms of a duplex mismatch, they quite literally negotiate between themselves which properties need to be used.

# %% [markdown]
# But if you do end up with a full duplex device trying to communicate with a half duplex device, this can result in the half duplex device stopping transmission and retransmitting packets at a later time. And it might list the interruption as a collision, or what's also known as a late collision error. But, in essence, it just doesn't understand, for a lack of a better word.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Identifying Mismatch
# ***

# %% [markdown]
# So identifying mismatches can be difficult.

# %% [markdown]
# So to be certain you can always configure the devices manually.

# %% [markdown]
# Most network adaptors have these properties that you can set but they're usually set to auto by default.

# %% [markdown]
# So it's more time consuming, of course, to configure them manually, but you can ensure that the links are operating at the desired speed and or the correct duplex setting. So it might take a little longer but it might also be a little more reliable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transceiver Mismatch - Medium Access Unit (MAU)
# ***

# %% [markdown]
# Now the transceiver, or what's often referred to as the MAU, or Medium Access Unit, is the actual component, the actual device used to send and receive signals.

# %% [markdown]
# And that goes for both analog and digital communications.

# %% [markdown]
# And in most cases the transceiver is built right into the network interface card for just about every modern adaptor. But in some cases depending on the age and or what the device is, the transceiver might be external, in which case that's where you need to ensure the correct properties are set.

# %% [markdown]
# So that whatever this transceiver is communicating with on the other end simply has the same configuration.

# %% [markdown]
# So really what you are looking to implement is consistency, so that you can avoid these mismatch problems.

# %% [markdown]
# And again, it's not that much of an issue these days for most adaptors and most devices, they will auto negotiate correctly.

# %% [markdown]
# But it is something to be on the lookout for if you have a mix of equipment, particularly older and newer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues7BadPortsBootlenecksandVLANMismatches"></a>
# ***
# ###### 7. Bad Ports, Bootlenecks, and VLAN Mismatches
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot bad ports, bottlenecks and VLAN mismatches``

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bad Ports
# ***

# %% [markdown]
# In this presentation, we'll take a look at some other issues that can arise from switch configuration, and/or just basic problems with a switch, including bad ports.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And of course, any port on any switch can go down at any time. It is, after all, just a piece of hardware.

# %% [markdown]
# So any kind of bad port will, of course, cause unexpected traffic drops, and performance issues.

# %% [markdown]
# So if you do identify any particular port on a switch as faulty, then you should consider labeling it, and/or even putting a piece of tape over it, so that no one can plug an actual cable into it.

# %% [markdown]
# Of course, this will help to prevent any future confusion.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bottlenecks - Hotspot
# ***

# %% [markdown]
# And there can also just be plain bottlenecks.

# %% [markdown]
# And a network bottleneck is often referred to as a hotspot, simply because it means there is a lot of traffic there.

# %% [markdown]
# But of course, this term these days generally refers to a wireless hotspot, so I don't hear that term all that often anymore. But this occurs when data flow becomes very limited, and the flow of data is, of course, controlled based on the bandwidth. But in some cases, there simply ends up being too much traffic trying to cross the same switch at any given time.

# %% [markdown]
# And it quite simply has to slow down. So the impact, of course, is just slower overall communication, and this in turn will reduce user efficiency, and user productivity.

# %% [markdown]
# And this is something that almost all of us have encountered at one point or another.

# %% [markdown]
# A common analogy is road traffic, particularly if it's due to an accident or construction, and there's only one lane of a highway that is open at the busiest time of day. Of course, on a highway that is normally two or more lanes, then everybody has to funnel into a single lane. So of course, everything just gets backed up and this is the same kind of thing that can actually happen with network traffic.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bottleneck Prevention
# ***

# %% [markdown]
# So in terms of prevention, many systems are built to handle a certain data flow capacity.

# %% [markdown]
# They have the appropriate processors built in. They have memory right on the network adapter cards. In many cases, there is a cache on the device. And of course, the network interface itself has different settings, different properties that you can configure, in terms of the control of flow.

# %% [markdown]
# So ideally, you want these to be at their most efficient settings, and in many cases that involves an auto negotiation.

# %% [markdown]
# So hopefully, your devices will be able to handle the data flow capacity of your environment, but if you discover that bottlenecks are happening all the time, particularly at a specific time of day. When things happen to be busiest then certainly you should go looking for some incorrect configurations, or of course hardware problems within those devices.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VLAN Mismatches - Incorrect VLAN Assignment
# ***

# %% [markdown]
# And finally, you might encounter an incorrect VLAN assignment on your switches.

# %% [markdown]
# The 802.1Q trunk again defines that all traffic be tagged with a VLAN ID, except for the native VLAN.

# %% [markdown]
# Any untagged traffic will be assigned to the native VLAN.

# %% [markdown]
# But if two switches connected to the trunk have different native VLANs configured, then the traffic will end up being assigned to the wrong one.

# %% [markdown]
# So we can see in the graphic, native VLAN 100 is configured on one side, and native VLAN 200 on the other. So in essence, it no longer knows which one is the correct native VLAN. [In the graphic displayed, the 802.1Q Trunk is placed between Native VLAN = 100 and Native VLAN = 200.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So all trunking switches should be configured for the same native VLAN to avoid these problems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Monitor - Correct - Prevent
# ***

# %% [markdown]
# So again, any number of problems can arise at your switches. And of course it is something that you always need to keep on top of. A little bit of monitoring of course can help to reduce these issues, or even correct them, or prevent them before they start.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues8DamagedCablesandBentPins"></a>
# ***
# ###### 8. Damaged Cables and Bent Pins
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot damaged cables and bent pins``

# %% [markdown]
# In this presentation we'll talk about some of the issues that can result from a damaged cable.

# %% [markdown]
# And, of course, this can entirely disrupt your service, or it may be a case where the performance is a little slower or intermittent.

# %% [markdown]
# Now that, of course, depends on the nature of the damage. If it is entirely broken and completely separated, then, of course, you will not get any connection whatsoever.

# %% [markdown]
# But if it's just frayed and there are a few connections that maybe able to touch each other, if the cable gets moved. For example if you have a laptop and maybe you just hang your cable on a little hook or something. And then you grab it and you plug it in and then you hang it back up so the cable moves a little bit.

# %% [markdown]
# Then there might be cases where it actually reestablishes the physical connection and/or pulls it apart. So then you might get literally off and on type of connectivity.

# %% [markdown]
# But for a scenario where the cable virtually never moves, physical damage can still result such as if you have somebody just tripping over a cable, or walking on it, or if it's running under a rug. Or perhaps it has been chewed through by a small animal. Things along those lines can still happen.

# %% [markdown]
# So the signs, of course, are looking for the visual damage. And if your Ethernet adapter light does not turn on, then there is no connectivity. Every connection that is made by an Ethernet cable should enable the connection light. And, in essence, if that is not coming on, then either the cable is unplugged at the other end, or there is a physical break, or just at least something wrong with that cable.

# %% [markdown]
# So, of course, the first solution really is to just replace it. And, of course, replace it with something that you know works. So a tested cable that is verified to be functioning, because if you just grab one from a box, maybe that box is for dead cables. So ensure that it is a functioning cable, test it to make sure that's the problem and then, of course, replace it.

# %% [markdown]
# And bent pins can also occur and this is not something that is unique to just network cables, if you have ever removed the processor from a system or examined an IDE hard drive close up. There are these gold colored pins on those physical components that can easily become bent because they are very soft and very small. So any kind of bent pin can often cause the component to not seat properly, which can result, of course, in connectivity or performance issues.

# %% [markdown]
# But with respect to network cables, it's not so much a matter of pins, but there are little contacts on the outside of the physical connector that connect to contacts on the inside of the adaptor. And they can become damaged, scratched, maybe even knocked off of the cable connector itself. So it's a similar problem. In which case there still is no means for a contact to actually be made. So always examine the actual physical connectors themselves as well, when trying to detect any kind of physical damage.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssues9LEDStatusIndicators"></a>
# ***
# ###### 9. LED Status Indicators
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot network connection LED status indicators``

# %% [markdown]
# Now when it comes to troubleshooting network connectivity, often a good place to start is the actual network card itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Card
# ***

# %% [markdown]
# This is your physical connection to the network.

# %% [markdown]
# Now most network interface cards are internal these days, but some of them can be external such as USB adapters.

# %% [markdown]
# But your adapter, even though it resides at the physical layer of the OSI model does not really provide you with much in terms of programming or decision making. It really is ultimately responsible for converting 1s and 0s into electrical impulses.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### LED Status Indicators
# ***

# %% [markdown]
# But it does actually give you a means to troubleshoot in the form of LED status indicators.

# %% [markdown]
# There is usually a status LED on virtually every network interface, and it will often have one of three states, solid, flashing or off.

# %% [markdown]
# Now there's a little bit of variance there to a degree and I'll come back to that in a moment.

# %% [markdown]
# But usually, a solid green light indicates that connectivity is present. So if, for example, you have a laptop and you plug the cable into the network interface, it should light up. And that indicates that it has successfully connected to something on the other end. If it does not, then there's something wrong with the cable or the connection on the other end, or possibly, of course, your own interface. But in essence, something is not working.

# %% [markdown]
# Now the flashing is a little bit of a relative term, because if you do plug it in and you get a solid light, as soon as traffic starts to pass over that interface, you'll usually see very rapid flashing, more like blinking. But if it's a very slow flash, like maybe once every second or half a second, then that usually indicates some kind of problem. And we'll see an example in moment.

# %% [markdown]
# So as mentioned, the flashing green is possibly a sign of intermittent connectivity. So this would be a fairly slow flash, again, maybe once every second or half a second. And that might indicate that either the network interface card or the Ethernet cable is going bad. There's some kind of problem that's not entirely gone but on its way out. But as I said, if you do have a solid stable connection then very often the flashing is very, very rapid. Looks more so like it's vibrating almost, or jittering if you will.

# %% [markdown]
# So flashing, again, is a little bit of a relative term, but this would be a fairly slow, very easily detectable flash.

# %% [markdown]
# You might also see a flashing amber, and this is generally an indication that there are collisions occurring on the network.

# %% [markdown]
# And solid amber is often an indication that there is a fault with the card itself.

# %% [markdown]
# If it's alternating green and amber very rapidly then the card might just be booting up. And if it's fairly slow, then the card might just be making DHCP requests, which in some cases might take a few minutes. But that ultimately should settle down and you should see, again, that solid green.

# %% [markdown]
# And once traffic starts to flow again, you might see that very rapid jittery flashing, but generally that's what you want to see.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Begin with Status Indicator
# ***

# %% [markdown]
# So if you aren't certain what the problem is or where to begin, then always check the status indicator on the network interface card. And that can hopefully get you started in the right direction.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssuespractice"></a>
# ***
# ### Practice: Wired Connectivity Issues
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot wired connectivity issues``

# %% [markdown]
# i. List some possible causes of network latency.
#
#
# ii. Then to describe methods used to reduce crosstalk on a network.
#
#
# iii. Then to describe how to identify incorrect cable types.
#
#
# iv. Finally to describe how to reduce bottlenecks.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssuesexercise"></a>
# ***
# ###### 1. Exercise: Troubleshoot Wired Connectivity Issues
# ***

# %% [markdown]
# i. List some possible causes of network latency.

# %% [markdown]
# - And this can include propagation to multiple different destinations.

# %% [markdown]
# - Variance of mediums such as copper versus fiber.

# %% [markdown]
# - Having too many interconnection devices such as routers and switches.

# %% [markdown]
# - And slow data access methods such as older hard drives.

# %% [markdown]
# All of them can certainly contribute to increased network latency.

# %% [markdown]
# ii. Then we asked to describe methods used to reduce crosstalk on a network.

# %% [markdown]
# - This can include using shielded cables or at least twisted pair cabling.

# %% [markdown]
# - Avoid proximity to other cables or other causes of electromagnetic interference. For example, try to avoid power cables, and separate the cables from each other if necessary.

# %% [markdown]
# iii. Then we asked to describe how to identify incorrect cable types.

# %% [markdown]
# And you can begin by comparing the wiring scheme at both ends of the cable. And it should match, depending of course on what its purpose is, so also verify the purpose. In other words, should you be using a straightthrough cable versus a crossover cable?

# %% [markdown]
# - Typically, if it is a computer to a switch, it would be a straightthrough.

# %% [markdown]
# - If it is computer to computer, then it should be a crossover.

# %% [markdown]
# So make sure you are using the correct cable for the correct purpose and then of course verify the wiring.

# %% [markdown]
# Also verify the category, such as category five versus category six.

# %% [markdown]
# And verify the physical connector, that it's the correct connector, and also that there is no damage.

# %% [markdown]
# iv. And finally we asked to describe how to reduce bottlenecks.

# %% [markdown]
# And this can involve ensuring consistent interface or device settings, ensuring that devices have their own processing, memory and caches. But in essence ensuring that you have the appropriate devices capable of handling the amount of traffic that your environment generates.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wiredConnectivityIssuesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
